# %%
# 1º) Baixar a biblioteca "requests"
#pip install requests

import requests

# 2º) buscar a API_KEY
api_key = "c5ded0f21ca54fab84a122730251804"

# 3º) pegar o link URL da API através de uma REQUEST (Requisição)
# URL_base = "http://api.weatherapi.com/v1" + clima_atual = "/current.json"
# URL = "http://api.weatherapi.com/v1/current.json"
link_api = "http://api.weatherapi.com/v1/current.json"
link_api_previsao = "http://api.weatherapi.com/v1/forecast.json"

# 4º) Para retirar o erro 401, devem ser repassados alguns parâmetros (request parameters), como 
# - chave da API (key)
# - Parâmetro do local a ser consultado (q)
cidade = input("Qual cidade você quer saber o clima atual? ")
dias = input("Para quantos dias você quer a previsão? ")
parametros = {
    "key": api_key, 
    "q": cidade, 
    "lang": "pt",
    "days": dias}

# Agora vamos coletar (get) as informações do link e armazenar na variável "resposta"
resposta = requests.get(link_api, params=parametros)
resposta2 = requests.get(link_api_previsao, params=parametros)

print(resposta.status_code)
print(resposta.content) # Resposta: API inválida ou não fornecida

print(resposta2.status_code)
print(resposta2.content)
# Out:
# 200
# b'{"location":{"name":"Campo Bom","region":"Rio Grande do Sul","country":"Brazil","lat":-29.6833,"lon":-51.05,"tz_id":"America/Sao_Paulo","localtime_epoch":1745005855,"localtime":"2025-04-18 16:50"},"current":{"last_updated_epoch":1745005500,"last_updated":"2025-04-18 16:45","temp_c":28.3,"temp_f":82.9,"is_day":1,"condition":{"text":"Parcialmente nublado","icon":"//cdn.weatherapi.com/weather/64x64/day/116.png","code":1003},"wind_mph":3.1,"wind_kph":5.0,"wind_degree":213,"wind_dir":"SSW","pressure_mb":1011.0,"pressure_in":29.85,"precip_mm":0.0,"precip_in":0.0,"humidity":66,"cloud":25,"feelslike_c":28.9,"feelslike_f":83.9,"windchill_c":28.7,"windchill_f":83.6,"heatindex_c":29.3,"heatindex_f":84.8,"dewpoint_c":16.5,"dewpoint_f":61.6,"vis_km":10.0,"vis_miles":6.0,"uv":1.4,"gust_mph":3.6,"gust_kph":5.8}}'
# 200
# b'{"location":{"name":"Campo Bom","region":"Rio Grande do Sul","country":"Brazil","lat":-29.6833,"lon":-51.05,"tz_id":"America/Sao_Paulo","localtime_epoch":1745005962,"localtime":"2025-04-18 16:52"},"current":{"last_updated_epoch":1745005500,"last_updated":"2025-04-18 16:45","temp_c":28.3,"temp_f":82.9,"is_day":1,"condition":{"text":"Parcialmente nublado","icon":"//cdn.weatherapi.com/weather/64x64/day/116.png","code":1003},"wind_mph":3.1,"wind_kph":5.0,"wind_degree":213,"wind_dir":"SSW","pressure_mb":1011.0,"pressure_in":29.85,"precip_mm":0.0,"precip_in":0.0,"humidity":66,"cloud":25,"feelslike_c":28.9,"feelslike_f":83.9,"windchill_c":28.7,"windchill_f":83.6,"heatindex_c":29.3,"heatindex_f":84.8,"dewpoint_c":16.5,"dewpoint_f":61.6,"vis_km":10.0,"vis_miles":6.0,"uv":1.4,"gust_mph":3.6,"gust_kph":5.8},"forecast":{"forecastday":[{"date":"2025-04-18","date_epoch":1744934400,"day":{"maxtemp_c":28.7,"maxtemp_f":83.6,"mintemp_c":17.6,"mintemp_f":63.8,"avgtemp_c":21.7,"avgtemp_f":71.1,"maxwind_mph":4.7,"maxwind_kph":7.6,"totalprecip_mm":0.0,"totalprecip_in":0.0,"totalsnow_cm":0.0,"avgvis_km":9.0,"avgvis_miles":5.0,"avghumidity":76,"daily_will_it_rain":0,"daily_chance_of_rain":0,"daily_will_it_snow":0,"daily_chance_of_snow":0,"condition":{"text":"Sol","icon":"//cdn.weatherapi.com/weather/64x64/day/113.png","code":1000},"uv":1.1},"astro":{"sunrise":"06:46 AM","sunset":"06:02 PM","moonrise":"09:48 PM","moonset":"11:51 AM","moon_phase":"Waning Gibbous","moon_illumination":79,"is_moon_up":1,"is_sun_up":0},"hour":[{"time_epoch":1744945200,"time":"2025-04-18 00:00","temp_c":18.8,"temp_f":65.9,"is_day":0,"condition":{"text":"Parcialmente nublado","icon":"//cdn.weatherapi.com/weather/64x64/night/116.png","code":1003},"wind_mph":4.0,"wind_kph":6.5,"wind_degree":110,"wind_dir":"ESE","pressure_mb":1014.0,"pressure_in":29.96,"precip_mm":0.0,"precip_in":0.0,"snow_cm":0.0,"humidity":92,"cloud":37,"feelslike_c":18.8,"feelslike_f":65.9,"windchill_c":18.8,"windchill_f":65.9,"heatindex_c":18.8,"heatindex_f":65.9,"dewpoint_c":17.5,"dewpoint_f":63.5,"will_it_rain":0,"chance_of_rain":0,"will_it_snow":0,"chance_of_snow":0,"vis_km":10.0,"vis_miles":6.0,"gust_mph":6.8,"gust_kph":10.9,"uv":0},{"time_epoch":1744948800,"time":"2025-04-18 01:00","temp_c":18.5,"temp_f":65.2,"is_day":0,"condition":{"text":"Parcialmente nublado","icon":"//cdn.weatherapi.com/weather/64x64/night/116.png","code":1003},"wind_mph":2.7,"wind_kph":4.3,"wind_degree":88,"wind_dir":"E","pressure_mb":1014.0,"pressure_in":29.94,"precip_mm":0.0,"precip_in":0.0,"snow_cm":0.0,"humidity":93,"cloud":38,"feelslike_c":18.5,"feelslike_f":65.2,"windchill_c":18.5,"windchill_f":65.2,"heatindex_c":18.5,"heatindex_f":65.2,"dewpoint_c":17.3,"dewpoint_f":63.1,"will_it_rain":0,"chance_of_rain":0,"will_it_snow":0,"chance_of_snow":0,"vis_km":10.0,"vis_miles":6.0,"gust_mph":4.6,"gust_kph":7.5,"uv":0},{"time_epoch":1744952400,"time":"2025-04-18 02:00","temp_c":18.2,"temp_f":64.7,"is_day":0,"condition":{"text":"Parcialmente nublado","icon":"//cdn.weatherapi.com/weather/64x64/night/116.png","code":1003},"wind_mph":2.9,"wind_kph":4.7,"wind_degree":70,"wind_dir":"ENE","pressure_mb":1014.0,"pressure_in":29.94,"precip_mm":0.0,"precip_in":0.0,"snow_cm":0.0,"humidity":94,"cloud":39,"feelslike_c":18.2,"feelslike_f":64.7,"windchill_c":18.2,"windchill_f":64.7,"heatindex_c":18.2,"heatindex_f":64.7,"dewpoint_c":17.1,"dewpoint_f":62.8,"will_it_rain":0,"chance_of_rain":0,"will_it_snow":0,"chance_of_snow":0,"vis_km":10.0,"vis_miles":6.0,"gust_mph":5.1,"gust_kph":8.3,"uv":0},{"time_epoch":1744956000,"time":"2025-04-18 03:00","temp_c":17.9,"temp_f":64.2,"is_day":0,"condition":{"text":"Neblina","icon":"//cdn.weatherapi.com/weather/64x64/night/143.png","code":1030},"wind_mph":1.8,"wind_kph":2.9,"wind_degree":77,"wind_dir":"ENE","pressure_mb":1014.0,"pressure_in":29.93,"precip_mm":0.0,"precip_in":0.0,"snow_cm":0.0,"humidity":94,"cloud":33,"feelslike_c":17.9,"feelslike_f":64.1,"windchill_c":17.9,"windchill_f":64.1,"heatindex_c":17.9,"he ...

# %% [markdown]
# # STATUS CODE:
# ## resposta 401 --> Não satisfez a requisição (Neste caso, sem autorização)
# No nosso exemplo, temos que passar pleo menos as requisições obrigatórias --> "KEY" e "Q" e opcionais (LANG)
# ## resposta 200 --> Deu certo a requisição
# # resposta 300 --> Requisição direcionada
# # resposta 500 --> servidor fora do ar

# %%
if resposta2.status_code == 200:
    dados_requisicao = resposta2.json() # Transforma a resposta json em um dicionario python
    print(dados_requisicao)
# Out:
# {'location': {'name': 'Campo Bom', 'region': 'Rio Grande do Sul', 'country': 'Brazil', 'lat': -29.6833, 'lon': -51.05, 'tz_id': 'America/Sao_Paulo', 'localtime_epoch': 1745005962, 'localtime': '2025-04-18 16:52'}, 'current': {'last_updated_epoch': 1745005500, 'last_updated': '2025-04-18 16:45', 'temp_c': 28.3, 'temp_f': 82.9, 'is_day': 1, 'condition': {'text': 'Parcialmente nublado', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 3.1, 'wind_kph': 5.0, 'wind_degree': 213, 'wind_dir': 'SSW', 'pressure_mb': 1011.0, 'pressure_in': 29.85, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 66, 'cloud': 25, 'feelslike_c': 28.9, 'feelslike_f': 83.9, 'windchill_c': 28.7, 'windchill_f': 83.6, 'heatindex_c': 29.3, 'heatindex_f': 84.8, 'dewpoint_c': 16.5, 'dewpoint_f': 61.6, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.4, 'gust_mph': 3.6, 'gust_kph': 5.8}, 'forecast': {'forecastday': [{'date': '2025-04-18', 'date_epoch': 1744934400, 'day': {'maxtemp_c': 28.7, 'maxtemp_f': 83.6, 'mintemp_c': 17.6, 'mintemp_f': 63.8, 'avgtemp_c': 21.7, 'avgtemp_f': 71.1, 'maxwind_mph': 4.7, 'maxwind_kph': 7.6, 'totalprecip_mm': 0.0, 'totalprecip_in': 0.0, 'totalsnow_cm': 0.0, 'avgvis_km': 9.0, 'avgvis_miles': 5.0, 'avghumidity': 76, 'daily_will_it_rain': 0, 'daily_chance_of_rain': 0, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Sol', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'uv': 1.1}, 'astro': {'sunrise': '06:46 AM', 'sunset': '06:02 PM', 'moonrise': '09:48 PM', 'moonset': '11:51 AM', 'moon_phase': 'Waning Gibbous', 'moon_illumination': 79, 'is_moon_up': 1, 'is_sun_up': 0}, 'hour': [{'time_epoch': 1744945200, 'time': '2025-04-18 00:00', 'temp_c': 18.8, 'temp_f': 65.9, 'is_day': 0, 'condition': {'text': 'Parcialmente nublado', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 4.0, 'wind_kph': 6.5, 'wind_degree': 110, 'wind_dir': 'ESE', 'pressure_mb': 1014.0, 'pressure_in': 29.96, 'precip_mm': 0.0, 'precip_in': 0.0, 'snow_cm': 0.0, 'humidity': 92, 'cloud': 37, 'feelslike_c': 18.8, 'feelslike_f': 65.9, 'windchill_c': 18.8, 'windchill_f': 65.9, 'heatindex_c': 18.8, 'heatindex_f': 65.9, 'dewpoint_c': 17.5, 'dewpoint_f': 63.5, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 6.8, 'gust_kph': 10.9, 'uv': 0}, {'time_epoch': 1744948800, 'time': '2025-04-18 01:00', 'temp_c': 18.5, 'temp_f': 65.2, 'is_day': 0, 'condition': {'text': 'Parcialmente nublado', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 2.7, 'wind_kph': 4.3, 'wind_degree': 88, 'wind_dir': 'E', 'pressure_mb': 1014.0, 'pressure_in': 29.94, 'precip_mm': 0.0, 'precip_in': 0.0, 'snow_cm': 0.0, 'humidity': 93, 'cloud': 38, 'feelslike_c': 18.5, 'feelslike_f': 65.2, 'windchill_c': 18.5, 'windchill_f': 65.2, 'heatindex_c': 18.5, 'heatindex_f': 65.2, 'dewpoint_c': 17.3, 'dewpoint_f': 63.1, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 4.6, 'gust_kph': 7.5, 'uv': 0}, {'time_epoch': 1744952400, 'time': '2025-04-18 02:00', 'temp_c': 18.2, 'temp_f': 64.7, 'is_day': 0, 'condition': {'text': 'Parcialmente nublado', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 2.9, 'wind_kph': 4.7, 'wind_degree': 70, 'wind_dir': 'ENE', 'pressure_mb': 1014.0, 'pressure_in': 29.94, 'precip_mm': 0.0, 'precip_in': 0.0, 'snow_cm': 0.0, 'humidity': 94, 'cloud': 39, 'feelslike_c': 18.2, 'feelslike_f': 64.7, 'windchill_c': 18.2, 'windchill_f': 64.7, 'heatindex_c': 18.2, 'heatindex_f': 64.7, 'dewpoint_c': 17.1, 'dewpoint_f': 62.8, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 5.1, 'gust_kph': 8.3, 'uv': 0}, {'time_epoch': 1744956000, 'time': '2025-04-18 03:00', 'temp_c': 17.9, 'temp_f': 64.2, 'is_day':  ...

# %%
# Podemos organizar melhor o print com o comando "pprint"
# Vamos importar a biblioteca pprint, já instalada no python
import pprint

pprint.pprint(dados_requisicao)
# Out:
# {'current': {'cloud': 25,
#              'condition': {'code': 1003,
#                            'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#                            'text': 'Parcialmente nublado'},
#              'dewpoint_c': 16.5,
#              'dewpoint_f': 61.6,
#              'feelslike_c': 28.9,
#              'feelslike_f': 83.9,
#              'gust_kph': 5.8,
#              'gust_mph': 3.6,
#              'heatindex_c': 29.3,
#              'heatindex_f': 84.8,
#              'humidity': 66,
#              'is_day': 1,
#              'last_updated': '2025-04-18 16:45',
#              'last_updated_epoch': 1745005500,
#              'precip_in': 0.0,
#              'precip_mm': 0.0,
#              'pressure_in': 29.85,
#              'pressure_mb': 1011.0,
#              'temp_c': 28.3,
#              'temp_f': 82.9,
#              'uv': 1.4,
#              'vis_km': 10.0,
#              'vis_miles': 6.0,
#              'wind_degree': 213,
#              'wind_dir': 'SSW',
#              'wind_kph': 5.0,
#              'wind_mph': 3.1,
#              'windchill_c': 28.7,
#              'windchill_f': 83.6},
#  'forecast': {'forecastday': [{'astro': {'is_moon_up': 1,
#                                          'is_sun_up': 0,
#                                          'moon_illumination': 79,
#                                          'moon_phase': 'Waning Gibbous',
#                                          'moonrise': '09:48 PM',
#                                          'moonset': '11:51 AM',
#                                          'sunrise': '06:46 AM',
#                                          'sunset': '06:02 PM'},
#                                'date': '2025-04-18',
#                                'date_epoch': 1744934400,
#                                'day': {'avghumidity': 76,
#                                        'avgtemp_c': 21.7,
#                                        'avgtemp_f': 71.1,
#                                        'avgvis_km': 9.0,
#                                        'avgvis_miles': 5.0,
#                                        'condition': {'code': 1000,
#                                                      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                      'text': 'Sol'},
#                                        'daily_chance_of_rain': 0,
#                                        'daily_chance_of_snow': 0,
#                                        'daily_will_it_rain': 0,
#                                        'daily_will_it_snow': 0,
#                                        'maxtemp_c': 28.7,
#                                        'maxtemp_f': 83.6,
#                                        'maxwind_kph': 7.6,
#                                        'maxwind_mph': 4.7,
#                                        'mintemp_c': 17.6,
#                                        'mintemp_f': 63.8,
#                                        'totalprecip_in': 0.0,
#                                        'totalprecip_mm': 0.0,
#                                        'totalsnow_cm': 0.0,
#                                        'uv': 1.1},
#                                'hour': [{'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 37,
#                                          'condition': {'code': 1003,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#                                                        'text': 'Parcialmente '
#                                                                'nublado'},
#                                          'dewpoint_c': 17.5,
#                                          'dewpoint_f': 63.5,
#                                          'feelslike_c': 18.8,
#                                          'feelslike_f': 65.9,
#                                          'gust_kph': 10.9,
#                                          'gust_mph': 6.8,
#                                          'heatindex_c': 18.8,
#                                          'heatindex_f': 65.9,
#                                          'humidity': 92,
#                                          'is_day': 0,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.96,
#                                          'pressure_mb': 1014.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 18.8,
#                                          'temp_f': 65.9,
#                                          'time': '2025-04-18 00:00',
#                                          'time_epoch': 1744945200,
#                                          'uv': 0,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 110,
#                                          'wind_dir': 'ESE',
#                                          'wind_kph': 6.5,
#                                          'wind_mph': 4.0,
#                                          'windchill_c': 18.8,
#                                          'windchill_f': 65.9},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 38,
#                                          'condition': {'code': 1003,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#                                                        'text': 'Parcialmente '
#                                                                'nublado'},
#                                          'dewpoint_c': 17.3,
#                                          'dewpoint_f': 63.1,
#                                          'feelslike_c': 18.5,
#                                          'feelslike_f': 65.2,
#                                          'gust_kph': 7.5,
#                                          'gust_mph': 4.6,
#                                          'heatindex_c': 18.5,
#                                          'heatindex_f': 65.2,
#                                          'humidity': 93,
#                                          'is_day': 0,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.94,
#                                          'pressure_mb': 1014.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 18.5,
#                                          'temp_f': 65.2,
#                                          'time': '2025-04-18 01:00',
#                                          'time_epoch': 1744948800,
#                                          'uv': 0,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 88,
#                                          'wind_dir': 'E',
#                                          'wind_kph': 4.3,
#                                          'wind_mph': 2.7,
#                                          'windchill_c': 18.5,
#                                          'windchill_f': 65.2},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 39,
#                                          'condition': {'code': 1003,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#                                                        'text': 'Parcialmente '
#                                                                'nublado'},
#                                          'dewpoint_c': 17.1,
#                                          'dewpoint_f': 62.8,
#                                          'feelslike_c': 18.2,
#                                          'feelslike_f': 64.7,
#                                          'gust_kph': 8.3,
#                                          'gust_mph': 5.1,
#                                          'heatindex_c': 18.2,
#                                          'heatindex_f': 64.7,
#                                          'humidity': 94,
#                                          'is_day': 0,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.94,
#                                          'pressure_mb': 1014.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 18.2,
#                                          'temp_f': 64.7,
#                                          'time': '2025-04-18 02:00',
#                                          'time_epoch': 1744952400,
#                                          'uv': 0,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 70,
#                                          'wind_dir': 'ENE',
#                                          'wind_kph': 4.7,
#                                          'wind_mph': 2.9,
#                                          'windchill_c': 18.2,
#                                          'windchill_f': 64.7},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 33,
#                                          'condition': {'code': 1030,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#                                                        'text': 'Neblina'},
#                                          'dewpoint_c': 16.9,
#                                          'dewpoint_f': 62.5,
#                                          'feelslike_c': 17.9,
#                                          'feelslike_f': 64.1,
#                                          'gust_kph': 5.3,
#                                          'gust_mph': 3.3,
#                                          'heatindex_c': 17.9,
#                                          'heatindex_f': 64.1,
#                                          'humidity': 94,
#                                          'is_day': 0,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.93,
#                                          'pressure_mb': 1014.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 17.9,
#                                          'temp_f': 64.2,
#                                          'time': '2025-04-18 03:00',
#                                          'time_epoch': 1744956000,
#                                          'uv': 0,
#                                          'vis_km': 2.0,
#                                          'vis_miles': 1.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 77,
#                                          'wind_dir': 'ENE',
#                                          'wind_kph': 2.9,
#                                          'wind_mph': 1.8,
#                                          'windchill_c': 17.9,
#                                          'windchill_f': 64.1},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 33,
#                                          'condition': {'code': 1030,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#                                                        'text': 'Neblina'},
#                                          'dewpoint_c': 16.8,
#                                          'dewpoint_f': 62.2,
#                                          'feelslike_c': 17.7,
#                                          'feelslike_f': 63.8,
#                                          'gust_kph': 3.3,
#                                          'gust_mph': 2.1,
#                                          'heatindex_c': 17.7,
#                                          'heatindex_f': 63.8,
#                                          'humidity': 95,
#                                          'is_day': 0,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.93,
#                                          'pressure_mb': 1013.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 17.7,
#                                          'temp_f': 63.8,
#                                          'time': '2025-04-18 04:00',
#                                          'time_epoch': 1744959600,
#                                          'uv': 0,
#                                          'vis_km': 2.0,
#                                          'vis_miles': 1.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 92,
#                                          'wind_dir': 'E',
#                                          'wind_kph': 1.8,
#                                          'wind_mph': 1.1,
#                                          'windchill_c': 17.7,
#                                          'windchill_f': 63.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 37,
#                                          'condition': {'code': 1030,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#                                                        'text': 'Neblina'},
#                                          'dewpoint_c': 16.7,
#                                          'dewpoint_f': 62.0,
#                                          'feelslike_c': 17.6,
#                                          'feelslike_f': 63.8,
#                                          'gust_kph': 4.0,
#                                          'gust_mph': 2.5,
#                                          'heatindex_c': 17.6,
#                                          'heatindex_f': 63.8,
#                                          'humidity': 94,
#                                          'is_day': 0,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.93,
#                                          'pressure_mb': 1013.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 17.6,
#                                          'temp_f': 63.8,
#                                          'time': '2025-04-18 05:00',
#                                          'time_epoch': 1744963200,
#                                          'uv': 0,
#                                          'vis_km': 2.0,
#                                          'vis_miles': 1.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 45,
#                                          'wind_dir': 'NE',
#                                          'wind_kph': 2.2,
#                                          'wind_mph': 1.3,
#                                          'windchill_c': 17.6,
#                                          'windchill_f': 63.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 22,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Céu limpo'},
#                                          'dewpoint_c': 16.7,
#                                          'dewpoint_f': 62.0,
#                                          'feelslike_c': 18.4,
#                                          'feelslike_f': 65.0,
#                                          'gust_kph': 4.9,
#                                          'gust_mph': 3.0,
#                                          'heatindex_c': 18.4,
#                                          'heatindex_f': 65.0,
#                                          'humidity': 90,
#                                          'is_day': 0,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.93,
#                                          'pressure_mb': 1014.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 18.3,
#                                          'temp_f': 65.0,
#                                          'time': '2025-04-18 06:00',
#                                          'time_epoch': 1744966800,
#                                          'uv': 0,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 11,
#                                          'wind_dir': 'NNE',
#                                          'wind_kph': 2.9,
#                                          'wind_mph': 1.8,
#                                          'windchill_c': 18.4,
#                                          'windchill_f': 65.0},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 14,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sol'},
#                                          'dewpoint_c': 16.1,
#                                          'dewpoint_f': 60.9,
#                                          'feelslike_c': 17.7,
#                                          'feelslike_f': 63.9,
#                                          'gust_kph': 5.1,
#                                          'gust_mph': 3.2,
#                                          'heatindex_c': 17.7,
#                                          'heatindex_f': 63.9,
#                                          'humidity': 90,
#                                          'is_day': 1,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.94,
#                                          'pressure_mb': 1014.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 17.7,
#                                          'temp_f': 63.9,
#                                          'time': '2025-04-18 07:00',
#                                          'time_epoch': 1744970400,
#                                          'uv': 0.0,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 316,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 2.9,
#                                          'wind_mph': 1.8,
#                                          'windchill_c': 17.7,
#                                          'windchill_f': 63.9},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 78,
#                                          'condition': {'code': 1006,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#                                                        'text': 'Nublado'},
#                                          'dewpoint_c': 16.3,
#                                          'dewpoint_f': 61.3,
#                                          'feelslike_c': 17.8,
#                                          'feelslike_f': 64.0,
#                                          'gust_kph': 5.0,
#                                          'gust_mph': 3.1,
#                                          'heatindex_c': 17.8,
#                                          'heatindex_f': 64.0,
#                                          'humidity': 91,
#                                          'is_day': 1,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.97,
#                                          'pressure_mb': 1015.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 17.8,
#                                          'temp_f': 64.0,
#                                          'time': '2025-04-18 08:00',
#                                          'time_epoch': 1744974000,
#                                          'uv': 0.3,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 294,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 2.9,
#                                          'wind_mph': 1.8,
#                                          'windchill_c': 17.8,
#                                          'windchill_f': 64.0},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 63,
#                                          'condition': {'code': 1006,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#                                                        'text': 'Nublado'},
#                                          'dewpoint_c': 16.4,
#                                          'dewpoint_f': 61.5,
#                                          'feelslike_c': 18.7,
#                                          'feelslike_f': 65.7,
#                                          'gust_kph': 5.7,
#                                          'gust_mph': 3.5,
#                                          'heatindex_c': 18.7,
#                                          'heatindex_f': 65.7,
#                                          'humidity': 86,
#                                          'is_day': 1,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.98,
#                                          'pressure_mb': 1015.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 18.7,
#                                          'temp_f': 65.7,
#                                          'time': '2025-04-18 09:00',
#                                          'time_epoch': 1744977600,
#                                          'uv': 1.3,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 345,
#                                          'wind_dir': 'NNW',
#                                          'wind_kph': 3.6,
#                                          'wind_mph': 2.2,
#                                          'windchill_c': 18.7,
#                                          'windchill_f': 65.7},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 56,
#                                          'condition': {'code': 1003,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#                                                        'text': 'Parcialmente '
#                                                                'nublado'},
#                                          'dewpoint_c': 16.3,
#                                          'dewpoint_f': 61.4,
#                                          'feelslike_c': 19.5,
#                                          'feelslike_f': 67.1,
#                                          'gust_kph': 6.0,
#                                          'gust_mph': 3.7,
#                                          'heatindex_c': 19.5,
#                                          'heatindex_f': 67.1,
#                                          'humidity': 82,
#                                          'is_day': 1,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.99,
#                                          'pressure_mb': 1016.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 19.5,
#                                          'temp_f': 67.1,
#                                          'time': '2025-04-18 10:00',
#                                          'time_epoch': 1744981200,
#                                          'uv': 1.3,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 356,
#                                          'wind_dir': 'N',
#                                          'wind_kph': 4.0,
#                                          'wind_mph': 2.5,
#                                          'windchill_c': 19.5,
#                                          'windchill_f': 67.1},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 17,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sol'},
#                                          'dewpoint_c': 16.4,
#                                          'dewpoint_f': 61.5,
#                                          'feelslike_c': 20.5,
#                                          'feelslike_f': 69.0,
#                                          'gust_kph': 4.1,
#                                          'gust_mph': 2.6,
#                                          'heatindex_c': 20.5,
#                                          'heatindex_f': 69.0,
#                                          'humidity': 77,
#                                          'is_day': 1,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.99,
#                                          'pressure_mb': 1015.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 20.5,
#                                          'temp_f': 69.0,
#                                          'time': '2025-04-18 11:00',
#                                          'time_epoch': 1744984800,
#                                          'uv': 2.0,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 328,
#                                          'wind_dir': 'NNW',
#                                          'wind_kph': 2.9,
#                                          'wind_mph': 1.8,
#                                          'windchill_c': 20.5,
#                                          'windchill_f': 69.0},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 7,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sol'},
#                                          'dewpoint_c': 16.7,
#                                          'dewpoint_f': 62.0,
#                                          'feelslike_c': 25.8,
#                                          'feelslike_f': 78.5,
#                                          'gust_kph': 4.6,
#                                          'gust_mph': 2.8,
#                                          'heatindex_c': 25.8,
#                                          'heatindex_f': 78.5,
#                                          'humidity': 62,
#                                          'is_day': 1,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.97,
#                                          'pressure_mb': 1015.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 24.4,
#                                          'temp_f': 76.0,
#                                          'time': '2025-04-18 12:00',
#                                          'time_epoch': 1744988400,
#                                          'uv': 5.2,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 293,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 4.0,
#                                          'wind_mph': 2.5,
#                                          'windchill_c': 24.4,
#                                          'windchill_f': 76.0},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 18,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sol'},
#                                          'dewpoint_c': 16.8,
#                                          'dewpoint_f': 62.2,
#                                          'feelslike_c': 27.7,
#                                          'feelslike_f': 81.9,
#                                          'gust_kph': 6.6,
#                                          'gust_mph': 4.1,
#                                          'heatindex_c': 27.7,
#                                          'heatindex_f': 81.9,
#                                          'humidity': 54,
#                                          'is_day': 1,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.95,
#                                          'pressure_mb': 1014.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 26.8,
#                                          'temp_f': 80.3,
#                                          'time': '2025-04-18 13:00',
#                                          'time_epoch': 1744992000,
#                                          'uv': 5.3,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 259,
#                                          'wind_dir': 'W',
#                                          'wind_kph': 5.8,
#                                          'wind_mph': 3.6,
#                                          'windchill_c': 26.9,
#                                          'windchill_f': 80.3},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 13,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sol'},
#                                          'dewpoint_c': 16.8,
#                                          'dewpoint_f': 62.2,
#                                          'feelslike_c': 28.5,
#                                          'feelslike_f': 83.2,
#                                          'gust_kph': 7.1,
#                                          'gust_mph': 4.4,
#                                          'heatindex_c': 28.5,
#                                          'heatindex_f': 83.2,
#                                          'humidity': 52,
#                                          'is_day': 1,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.92,
#                                          'pressure_mb': 1013.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 27.7,
#                                          'temp_f': 81.8,
#                                          'time': '2025-04-18 14:00',
#                                          'time_epoch': 1744995600,
#                                          'uv': 4.9,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 238,
#                                          'wind_dir': 'WSW',
#                                          'wind_kph': 6.1,
#                                          'wind_mph': 3.8,
#                                          'windchill_c': 27.7,
#                                          'windchill_f': 81.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 7,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sol'},
#                                          'dewpoint_c': 16.6,
#                                          'dewpoint_f': 61.9,
#                                          'feelslike_c': 29.1,
#                                          'feelslike_f': 84.5,
#                                          'gust_kph': 7.5,
#                                          'gust_mph': 4.6,
#                                          'heatindex_c': 29.1,
#                                          'heatindex_f': 84.5,
#                                          'humidity': 49,
#                                          'is_day': 1,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.89,
#                                          'pressure_mb': 1012.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 28.4,
#                                          'temp_f': 83.2,
#                                          'time': '2025-04-18 15:00',
#                                          'time_epoch': 1744999200,
#                                          'uv': 3.1,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 240,
#                                          'wind_dir': 'WSW',
#                                          'wind_kph': 6.5,
#                                          'wind_mph': 4.0,
#                                          'windchill_c': 28.4,
#                                          'windchill_f': 83.2},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 25,
#                                          'condition': {'code': 1003,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#                                                        'text': 'Parcialmente '
#                                                                'nublado'},
#                                          'dewpoint_c': 16.5,
#                                          'dewpoint_f': 61.6,
#                                          'feelslike_c': 29.3,
#                                          'feelslike_f': 84.8,
#                                          'gust_kph': 5.8,
#                                          'gust_mph': 3.6,
#                                          'heatindex_c': 29.3,
#                                          'heatindex_f': 84.8,
#                                          'humidity': 66,
#                                          'is_day': 1,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.85,
#                                          'pressure_mb': 1011.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 28.3,
#                                          'temp_f': 82.9,
#                                          'time': '2025-04-18 16:00',
#                                          'time_epoch': 1745002800,
#                                          'uv': 1.4,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 213,
#                                          'wind_dir': 'SSW',
#                                          'wind_kph': 5.0,
#                                          'wind_mph': 3.1,
#                                          'windchill_c': 28.7,
#                                          'windchill_f': 83.6},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 7,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sol'},
#                                          'dewpoint_c': 16.5,
#                                          'dewpoint_f': 61.6,
#                                          'feelslike_c': 29.0,
#                                          'feelslike_f': 84.1,
#                                          'gust_kph': 7.3,
#                                          'gust_mph': 4.6,
#                                          'heatindex_c': 29.0,
#                                          'heatindex_f': 84.1,
#                                          'humidity': 49,
#                                          'is_day': 1,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.86,
#                                          'pressure_mb': 1011.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 28.3,
#                                          'temp_f': 82.9,
#                                          'time': '2025-04-18 17:00',
#                                          'time_epoch': 1745006400,
#                                          'uv': 0.4,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 187,
#                                          'wind_dir': 'S',
#                                          'wind_kph': 5.8,
#                                          'wind_mph': 3.6,
#                                          'windchill_c': 28.3,
#                                          'windchill_f': 82.9},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 7,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sol'},
#                                          'dewpoint_c': 17.8,
#                                          'dewpoint_f': 64.1,
#                                          'feelslike_c': 28.0,
#                                          'feelslike_f': 82.4,
#                                          'gust_kph': 7.8,
#                                          'gust_mph': 4.9,
#                                          'heatindex_c': 28.0,
#                                          'heatindex_f': 82.4,
#                                          'humidity': 58,
#                                          'is_day': 1,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.87,
#                                          'pressure_mb': 1011.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 26.9,
#                                          'temp_f': 80.4,
#                                          'time': '2025-04-18 18:00',
#                                          'time_epoch': 1745010000,
#                                          'uv': 0.0,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 165,
#                                          'wind_dir': 'SSE',
#                                          'wind_kph': 5.0,
#                                          'wind_mph': 3.1,
#                                          'windchill_c': 26.9,
#                                          'windchill_f': 80.4},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 8,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Céu limpo'},
#                                          'dewpoint_c': 17.1,
#                                          'dewpoint_f': 62.7,
#                                          'feelslike_c': 25.4,
#                                          'feelslike_f': 77.8,
#                                          'gust_kph': 12.9,
#                                          'gust_mph': 8.0,
#                                          'heatindex_c': 25.4,
#                                          'heatindex_f': 77.8,
#                                          'humidity': 66,
#                                          'is_day': 0,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 29.89,
#                                          'pressure_mb': 1012.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 23.8,
#                                          'temp_f': 74.8,
#                                          'time': '2025-04-18 19:00',
#                                          'time_epoch': 1745013600,
#                                          'uv': 0,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 146,
#                                          'wind_dir': 'SSE',
#                                          'wind_kph': 6.1,
#                                          'wind_mph': 3.8,
# ...
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 13,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sol'},
#                                          'dewpoint_c': 10.6,
#                                          'dewpoint_f': 51.1,
#                                          'feelslike_c': 21.7,
#                                          'feelslike_f': 71.1,
#                                          'gust_kph': 16.4,
#                                          'gust_mph': 10.2,
#                                          'heatindex_c': 24.3,
#                                          'heatindex_f': 75.8,
#                                          'humidity': 49,
#                                          'is_day': 1,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 30.02,
#                                          'pressure_mb': 1016.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 21.7,
#                                          'temp_f': 71.1,
#                                          'time': '2025-04-19 17:00',
#                                          'time_epoch': 1745092800,
#                                          'uv': 0.3,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 153,
#                                          'wind_dir': 'SSE',
#                                          'wind_kph': 13.7,
#                                          'wind_mph': 8.5,
#                                          'windchill_c': 21.7,
#                                          'windchill_f': 71.1},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 10,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sol'},
#                                          'dewpoint_c': 10.3,
#                                          'dewpoint_f': 50.6,
#                                          'feelslike_c': 20.4,
#                                          'feelslike_f': 68.7,
#                                          'gust_kph': 18.5,
#                                          'gust_mph': 11.5,
#                                          'heatindex_c': 20.4,
#                                          'heatindex_f': 68.7,
#                                          'humidity': 52,
#                                          'is_day': 1,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 30.02,
#                                          'pressure_mb': 1017.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 20.4,
#                                          'temp_f': 68.7,
#                                          'time': '2025-04-19 18:00',
#                                          'time_epoch': 1745096400,
#                                          'uv': 0.0,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 152,
#                                          'wind_dir': 'SSE',
#                                          'wind_kph': 13.7,
#                                          'wind_mph': 8.5,
#                                          'windchill_c': 20.4,
#                                          'windchill_f': 68.7},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 12,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Céu limpo'},
#                                          'dewpoint_c': 9.7,
#                                          'dewpoint_f': 49.5,
#                                          'feelslike_c': 18.3,
#                                          'feelslike_f': 64.9,
#                                          'gust_kph': 19.0,
#                                          'gust_mph': 11.8,
#                                          'heatindex_c': 18.3,
#                                          'heatindex_f': 64.9,
#                                          'humidity': 57,
#                                          'is_day': 0,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 30.03,
#                                          'pressure_mb': 1017.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 18.3,
#                                          'temp_f': 64.9,
#                                          'time': '2025-04-19 19:00',
#                                          'time_epoch': 1745100000,
#                                          'uv': 0,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 146,
#                                          'wind_dir': 'SSE',
#                                          'wind_kph': 11.9,
#                                          'wind_mph': 7.4,
#                                          'windchill_c': 18.3,
#                                          'windchill_f': 64.9},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 13,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Céu limpo'},
#                                          'dewpoint_c': 9.4,
#                                          'dewpoint_f': 49.0,
#                                          'feelslike_c': 17.3,
#                                          'feelslike_f': 63.1,
#                                          'gust_kph': 17.5,
#                                          'gust_mph': 10.9,
#                                          'heatindex_c': 17.3,
#                                          'heatindex_f': 63.1,
#                                          'humidity': 60,
#                                          'is_day': 0,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 30.05,
#                                          'pressure_mb': 1018.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 17.3,
#                                          'temp_f': 63.1,
#                                          'time': '2025-04-19 20:00',
#                                          'time_epoch': 1745103600,
#                                          'uv': 0,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 142,
#                                          'wind_dir': 'SE',
#                                          'wind_kph': 10.4,
#                                          'wind_mph': 6.5,
#                                          'windchill_c': 17.3,
#                                          'windchill_f': 63.1},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 13,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Céu limpo'},
#                                          'dewpoint_c': 9.2,
#                                          'dewpoint_f': 48.6,
#                                          'feelslike_c': 16.6,
#                                          'feelslike_f': 62.0,
#                                          'gust_kph': 14.5,
#                                          'gust_mph': 9.0,
#                                          'heatindex_c': 16.6,
#                                          'heatindex_f': 62.0,
#                                          'humidity': 62,
#                                          'is_day': 0,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 30.06,
#                                          'pressure_mb': 1018.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 16.6,
#                                          'temp_f': 61.9,
#                                          'time': '2025-04-19 21:00',
#                                          'time_epoch': 1745107200,
#                                          'uv': 0,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 138,
#                                          'wind_dir': 'SE',
#                                          'wind_kph': 8.3,
#                                          'wind_mph': 5.1,
#                                          'windchill_c': 16.6,
#                                          'windchill_f': 62.0},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 10,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Céu limpo'},
#                                          'dewpoint_c': 9.2,
#                                          'dewpoint_f': 48.6,
#                                          'feelslike_c': 16.1,
#                                          'feelslike_f': 60.9,
#                                          'gust_kph': 12.2,
#                                          'gust_mph': 7.6,
#                                          'heatindex_c': 16.1,
#                                          'heatindex_f': 60.9,
#                                          'humidity': 64,
#                                          'is_day': 0,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 30.08,
#                                          'pressure_mb': 1019.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 16.1,
#                                          'temp_f': 60.9,
#                                          'time': '2025-04-19 22:00',
#                                          'time_epoch': 1745110800,
#                                          'uv': 0,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 129,
#                                          'wind_dir': 'SE',
#                                          'wind_kph': 6.8,
#                                          'wind_mph': 4.3,
#                                          'windchill_c': 16.1,
#                                          'windchill_f': 60.9},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 7,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Céu limpo'},
#                                          'dewpoint_c': 9.3,
#                                          'dewpoint_f': 48.7,
#                                          'feelslike_c': 15.5,
#                                          'feelslike_f': 59.9,
#                                          'gust_kph': 12.2,
#                                          'gust_mph': 7.6,
#                                          'heatindex_c': 15.5,
#                                          'heatindex_f': 59.9,
#                                          'humidity': 66,
#                                          'is_day': 0,
#                                          'precip_in': 0.0,
#                                          'precip_mm': 0.0,
#                                          'pressure_in': 30.09,
#                                          'pressure_mb': 1019.0,
#                                          'snow_cm': 0.0,
#                                          'temp_c': 15.5,
#                                          'temp_f': 59.9,
#                                          'time': '2025-04-19 23:00',
#                                          'time_epoch': 1745114400,
#                                          'uv': 0,
#                                          'vis_km': 10.0,
#                                          'vis_miles': 6.0,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 114,
#                                          'wind_dir': 'ESE',
#                                          'wind_kph': 6.8,
#                                          'wind_mph': 4.3,
#                                          'windchill_c': 15.5,
#                                          'windchill_f': 59.9}]}]},
#  'location': {'country': 'Brazil',
#               'lat': -29.6833,
#               'localtime': '2025-04-18 16:52',
#               'localtime_epoch': 1745005962,
#               'lon': -51.05,
#               'name': 'Campo Bom',
#               'region': 'Rio Grande do Sul',
#               'tz_id': 'America/Sao_Paulo'}}

# %%
# Agora fica mais fácil obter os dados que queremos printar:
temperatura = dados_requisicao["current"]["temp_c"]
desc_tempo = dados_requisicao["current"]["condition"]["text"]
cidade = dados_requisicao["location"]["name"]

print(f"A cidade de {cidade} está com o tempo '{desc_tempo}' e com a temperatura de {temperatura}ºC")
# Out:
# A cidade de Campo Bom está com o tempo 'Parcialmente nublado' e com a temperatura de 28.3ºC
